# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data/citibike_2019_sample.csv")
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           574  2019-01-30 17:30:59.7870  2019-01-30 17:40:34.2530
# 1           709  2019-01-23 19:28:12.1530  2019-01-23 19:40:01.7030
# 2          1993  2019-01-26 18:30:29.2160  2019-01-26 19:03:43.0780
# 3           392  2019-01-05 18:31:40.6190  2019-01-05 18:38:13.1980
# 4           543  2019-01-23 15:24:24.9240  2019-01-23 15:33:28.8630
#
#    start station id     start station name  start station latitude  \
# 0             359.0     E 47 St & Park Ave               40.755103
# 1             493.0        W 45 St & 6 Ave               40.756800
# 2             503.0     E 20 St & Park Ave               40.738274
# 3             161.0  LaGuardia Pl & W 3 St               40.729170
# 4            3496.0       1 Ave & E 110 St               40.792327
#
#    start station longitude  end station id     end station name  \
# 0               -73.974987           528.0      2 Ave & E 31 St
# ...

# %%
len(df)
# Out:
# 411032

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411032 entries, 0 to 411031
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             411032 non-null  int64
#  1   starttime                411032 non-null  object
#  2   stoptime                 411032 non-null  object
#  3   start station id         411023 non-null  float64
#  4   start station name       411023 non-null  object
#  5   start station latitude   411032 non-null  float64
#  6   start station longitude  411032 non-null  float64
#  7   end station id           411023 non-null  float64
#  8   end station name         411023 non-null  object
#  9   end station latitude     411032 non-null  float64
#  10  end station longitude    411032 non-null  float64
#  11  bikeid                   411032 non-null  int64
#  12  usertype                 411032 non-null  object
# ...

# %%
df2=df.dropna()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 411023 entries, 0 to 411031
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             411023 non-null  int64
#  1   starttime                411023 non-null  object
#  2   stoptime                 411023 non-null  object
#  3   start station id         411023 non-null  float64
#  4   start station name       411023 non-null  object
#  5   start station latitude   411023 non-null  float64
#  6   start station longitude  411023 non-null  float64
#  7   end station id           411023 non-null  float64
#  8   end station name         411023 non-null  object
#  9   end station latitude     411023 non-null  float64
#  10  end station longitude    411023 non-null  float64
#  11  bikeid                   411023 non-null  int64
#  12  usertype                 411023 non-null  object
# ...

# %%
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           574  2019-01-30 17:30:59.7870  2019-01-30 17:40:34.2530
# 1           709  2019-01-23 19:28:12.1530  2019-01-23 19:40:01.7030
# 2          1993  2019-01-26 18:30:29.2160  2019-01-26 19:03:43.0780
# 3           392  2019-01-05 18:31:40.6190  2019-01-05 18:38:13.1980
# 4           543  2019-01-23 15:24:24.9240  2019-01-23 15:33:28.8630
#
#    start station id     start station name  start station latitude  \
# 0             359.0     E 47 St & Park Ave               40.755103
# 1             493.0        W 45 St & 6 Ave               40.756800
# 2             503.0     E 20 St & Park Ave               40.738274
# 3             161.0  LaGuardia Pl & W 3 St               40.729170
# 4            3496.0       1 Ave & E 110 St               40.792327
#
#    start station longitude  end station id     end station name  \
# 0               -73.974987           528.0      2 Ave & E 31 St
# ...

# %%
5000 / 411023
# Out:
# 0.012164769368137549

# %%
df3 = df2.sample(frac=0.0122)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5014 entries, 392324 to 325469
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             5014 non-null   int64
#  1   starttime                5014 non-null   object
#  2   stoptime                 5014 non-null   object
#  3   start station id         5014 non-null   float64
#  4   start station name       5014 non-null   object
#  5   start station latitude   5014 non-null   float64
#  6   start station longitude  5014 non-null   float64
#  7   end station id           5014 non-null   float64
#  8   end station name         5014 non-null   object
#  9   end station latitude     5014 non-null   float64
#  10  end station longitude    5014 non-null   float64
#  11  bikeid                   5014 non-null   int64
#  12  usertype                 5014 non-null   object
# ...

# %%
df3.head()
# Out:
#         tripduration                 starttime                  stoptime  \
# 392324           564  2019-12-15 12:18:03.3490  2019-12-15 12:27:27.7590
# 159359           382  2019-06-30 18:44:18.0230  2019-06-30 18:50:40.1990
# 348578           168  2019-10-16 08:50:40.3190  2019-10-16 08:53:29.0610
# 21253            624  2019-02-16 18:49:47.3750  2019-02-16 19:00:11.6180
# 144858           936  2019-06-28 09:32:26.7150  2019-06-28 09:48:02.7260
#
#         start station id       start station name  start station latitude  \
# 392324             507.0          E 25 St & 2 Ave               40.739126
# 159359             303.0    Mercer St & Spring St               40.723627
# 348578             257.0  Lispenard St & Broadway               40.719392
# 21253              349.0  Rivington St & Ridge St               40.718502
# 144858             514.0         12 Ave & W 40 St               40.760875
#
#         start station longitude  end station id             end station name  \
# ...

# %%
df3.to_csv("Data/citibike_rides_sample.csv", index=False)
